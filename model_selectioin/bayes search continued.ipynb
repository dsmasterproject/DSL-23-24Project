# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import csv
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse 
from skopt import BayesSearchCV

# %%
development = pd.read_csv(r'c:\Users\zamuc\OneDrive\Desktop\bayes babe\development.csv')
evaluation = pd.read_csv(r'c:\Users\zamuc\OneDrive\Desktop\bayes babe\evaluation.csv')

# %%
df = pd.concat([development, evaluation], sort=False)

# %%
df.set_index('Id', inplace=True)

# %%
outliers_idx = [0,7,12,15,16,17]
dropped_cols = ['pmax[%s]' %i for i in outliers_idx]+['negpmax[%s]' %i for i in outliers_idx]+['area[%s]' %i for i in outliers_idx]+['tmax[%s]' %i for i in outliers_idx]+['rms[%s]' %i for i in outliers_idx]
print(dropped_cols)
# Out:
# ['pmax[0]', 'pmax[7]', 'pmax[12]', 'pmax[15]', 'pmax[16]', 'pmax[17]', 'negpmax[0]', 'negpmax[7]', 'negpmax[12]', 'negpmax[15]', 'negpmax[16]', 'negpmax[17]', 'area[0]', 'area[7]', 'area[12]', 'area[15]', 'area[16]', 'area[17]', 'tmax[0]', 'tmax[7]', 'tmax[12]', 'tmax[15]', 'tmax[16]', 'tmax[17]', 'rms[0]', 'rms[7]', 'rms[12]', 'rms[15]', 'rms[16]', 'rms[17]']

# %%
df = df.drop(columns=dropped_cols)
display(df)
# Out:
#               x      y    pmax[1]  negpmax[1]    area[1]     tmax[1]  \
# Id
# NaN       200.0  200.0   5.409161  -17.721210   4.538778   22.600000
# NaN       200.0  200.0   4.414289   -4.736827   3.720435  111.875058
# NaN       200.0  200.0   4.567191   -5.985437   3.490490  107.800000
# NaN       200.0  200.0   5.019058   -4.229949   6.786200  175.600000
# NaN       200.0  200.0   3.250262   -5.783587   2.449456  159.800000
# ...         ...    ...        ...         ...        ...         ...
# 128495.0    NaN    NaN   9.327438   -3.704605   6.657654   71.400000
# 128496.0    NaN    NaN   5.833882   -6.185739   4.184656   20.037256
# 128497.0    NaN    NaN  19.402353   -8.160696  11.304202   70.800000
# 128498.0    NaN    NaN   4.200095   -5.312485   2.652198   71.400000
# 128499.0    NaN    NaN   5.997916   -5.558389   3.536047   72.000000
#
#             rms[1]    pmax[2]  negpmax[2]    area[2]  ...   pmax[13]  \
# Id                                                    ...
# ...

# %%
coord=['x', 'y']
test_mask = df['x'].isna() & df['y'].isna()

X = df.drop(columns=coord).values
y = df[coord].values

X_train_valid = X[~test_mask]
y_train_valid = y[~test_mask]

X_test = X[test_mask]
y_test = y[test_mask]

from sklearn.model_selection import train_test_split
rs = 2024

X_train, X_valid, y_train, y_valid = train_test_split(X_train_valid,y_train_valid,shuffle=True, random_state=rs)

# %%
parameters = {"n_estimators":[100,250], "max_depth":[50,100], "min_samples_split": [2,5,10], "max_features":[ "sqrt", "log2"], "random_state":[rs], "n_jobs":[-1] } 
bayes = BayesSearchCV(RandomForestRegressor(), search_spaces=parameters, scoring="r2", cv=5, n_iter=50, n_jobs=-1, random_state=rs)

# %%
np.int = int
bayes.fit(X_train_valid, y_train_valid)
# Out:
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# ...

# %%
bayes.best_params_
# Out:
# OrderedDict([('max_depth', 100),
#              ('max_features', 'sqrt'),
#              ('min_samples_split', 5),
#              ('n_estimators', 100),
#              ('n_jobs', -1),
#              ('random_state', 2024)])

# %% [markdown]
# Inserisci sotto i valori dei parametri che hai ottenuto sopra

# %%
rfr = RandomForestRegressor(n_estimators= 100,min_samples_split= 5,max_features='sqrt',max_depth= 100 ,random_state=rs, n_jobs= -1)
rfr.fit(X_train, y_train)
y_rfr=rfr.predict(X_test)
distance=np.mean(np.sqrt(np.sum((y_rfr - y_test) ** 2, axis=1)))
print(distance)
evaluation = evaluation.drop(columns=dropped_cols)
eva_df = evaluation.drop(columns=['Id'])
eva_y=rfr.predict(eva_df)

df = pd.DataFrame(eva_y, columns=['Id', 'Predicted'])
df['Predicted'] = df.apply(lambda row: f"{row['Id']:.1f}|{row['Predicted']:.1f}", axis=1)
df['Id'] = df.index
df.to_csv('outputbayes2.csv', index=False, sep=',')
# Out:
# nan
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(

# %%
bayes.best_score_
# Out:
# -0.2978700926162214

# %%
y_pred = bayes.predict(X_test) 
pd.DataFrame(y_pred, index=df[test_mask].index).to_csv("output.csv",index_label="Id", header=["Predicted"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 y_pred = bayes.predict(X_test)
# ----> 2 pd.DataFrame(y_pred, index=df[test_mask].index).to_csv("output.csv",index_label="Id", header=["Predicted"])
#
# File c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
eva_y=rfr.predict(eva_df)

df = pd.DataFrame(eva_y, columns=['Id', 'Predicted'])
df['Predicted'] = df.apply(lambda row: f"{row['Id']:.1f}|{row['Predicted']:.1f}", axis=1)
df['Id'] = df.index
df.to_csv('outputbayes2.csv', index=False, sep=',')

# %%
parameters = {"n_estimators":[100,250,350], "max_depth":[100,150,200,300], "min_samples_split": [2,5,10,15], "max_features":[ "sqrt", "log2"], "random_state":[rs], "n_jobs":[-1] } 
bayes = BayesSearchCV(RandomForestRegressor(), search_spaces=parameters, scoring="r2", cv=5, n_iter=50, n_jobs=-1, random_state=rs)

# %%
np.int = int
bayes.fit(X_train_valid, y_train_valid)
# Out:
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# ...

# %%
bayes.best_params_
# Out:
# OrderedDict([('max_depth', 200),
#              ('max_features', 'sqrt'),
#              ('min_samples_split', 5),
#              ('n_estimators', 100),
#              ('n_jobs', -1),
#              ('random_state', 2024)])

# %%
bayes.best_score_
# Out:
# -0.2978700926162213

# %%
rfr = RandomForestRegressor(n_estimators= 100,min_samples_split= 5,max_features='sqrt',max_depth= 200 ,random_state=rs, n_jobs= -1)
rfr.fit(X_train, y_train)
y_rfr=rfr.predict(X_test)
distance=np.mean(np.sqrt(np.sum((y_rfr - y_test) ** 2, axis=1)))
print(distance)

eva_y=rfr.predict(eva_df)

df = pd.DataFrame(eva_y, columns=['Id', 'Predicted'])
df['Predicted'] = df.apply(lambda row: f"{row['Id']:.1f}|{row['Predicted']:.1f}", axis=1)
df['Id'] = df.index
df.to_csv('outputbayes3.csv', index=False, sep=',')
# Out:
# nan
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(

# %%
parameters = {"n_estimators":[150, 200, 250], "max_depth":[150,200,250], "min_samples_split": [2,5,10], "max_features":[ "sqrt"], "random_state":[rs], "n_jobs":[-1] } 
bayes = BayesSearchCV(RandomForestRegressor(), search_spaces=parameters, scoring="r2", cv=5, n_iter=100, n_jobs=-1, random_state=rs)

# %%
np.int = int
bayes.fit(X_train_valid, y_train_valid)
# Out:
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# ...

# %%
bayes.best_params_
# Out:
# OrderedDict([('max_depth', 250),
#              ('max_features', 'sqrt'),
#              ('min_samples_split', 5),
#              ('n_estimators', 150),
#              ('n_jobs', -1),
#              ('random_state', 2024)])

# %%
bayes.best_score_
# Out:
# -0.30734136387701827

# %%
rfr = RandomForestRegressor(n_estimators= 150,min_samples_split= 5,max_features='sqrt',max_depth= 250,random_state=rs, n_jobs= -1)
rfr.fit(X_train, y_train)
y_rfr=rfr.predict(X_test)
distance=np.mean(np.sqrt(np.sum((y_rfr - y_test) ** 2, axis=1)))
print(distance)

eva_y=rfr.predict(eva_df)

df = pd.DataFrame(eva_y, columns=['Id', 'Predicted'])
df['Predicted'] = df.apply(lambda row: f"{row['Id']:.1f}|{row['Predicted']:.1f}", axis=1)
df['Id'] = df.index
df.to_csv('outputbayes4.csv', index=False, sep=',')
# Out:
# nan
# c:\Users\zamuc\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
